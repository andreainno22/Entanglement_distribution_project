# %%
import qiskit
from qiskit_aer import AerSimulator

print("Versione Qiskit:", qiskit.__version__)
# Test del simulatore
sim = AerSimulator()
print("Simulatore pronto:", sim.name)
# Out:
# Versione Qiskit: 2.4.2
# Simulatore pronto: aer_simulator
